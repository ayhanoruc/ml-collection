# %%
import tensorflow as tf
import numpy as np

# %% [markdown]
# ### vectorizing the text
# - unique set of elements
# - char2idx
# - encoding
# - idx2char: decoding

# %% [markdown]
# ### create the dataset as input-target sequence tuples

# %% [markdown]
# ### build the model

# %% [markdown]
# ### Compiling and Training and saving the model checkpoint

# %% [markdown]
# ### Generating Text
